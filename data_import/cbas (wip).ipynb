# %%
import os
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
os.getcwd()
# Out:
# '/Users/caseyh/Desktop/footyfootyfooty/data_import'

# %%
path = '/Users/caseyh/Desktop/footyfootyfooty/dfs_2023_player_stats.csv'

# %%
df = pd.read_csv(path,skiprows = 3)

# %%
df.head()
# Out:
#            player team opponent  year  round  kicks  handballs  marks  \
# 0   Jordan Dawson  ADE      NTH  2023     16     22          6      8
# 1  Reilly O'Brien  ADE      NTH  2023     16      7          8      4
# 2       Ben Keays  ADE      NTH  2023     16     14         15      5
# 3  Mitchell Hinge  ADE      NTH  2023     16     22          4     10
# 4     Rory Sloane  ADE      NTH  2023     16     17         13      7
#
#    tackles  hitouts  ...  freesAgainst  goals  behinds  cbas  kickins  \
# 0        8        0  ...             0      0        0    26        0
# 1        5       52  ...             1      2        1    32        0
# 2        7        0  ...             0      2        2     1        0
# 3        3        0  ...             0      0        1     0        0
# 4        5        0  ...             2      0        0    11        0
#
#    kickinsPlayon  tog  fantasyPoints  superCoachPoints  namedPosition
# 0              0   88            136               102              C
# 1              0   88            133               144             RK
# 2              0   86            132               124              R
# 3              0   77            119               110           HBFL
# 4              0   80            112                89             WR
#
# [5 rows x 22 columns]

# %%
df.to_csv(path, index = False)
