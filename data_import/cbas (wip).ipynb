# %%
import os
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
os.getcwd()
# Out:
# '/Users/caseyh/Desktop/footyfootyfooty/data_import'

# %%
path = '/Users/caseyh/Desktop/footyfootyfooty/dfs_2023_player_stats.csv'

# %%
df = pd.read_csv(path, header=None)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 df = pd.read_csv(path, header=None)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df.head()
# Out:
#                                                    0
# 0  Stats downloaded from Daily Fantasy Sports Aus...
# 1  Help us to continue providing free content by ...
# 2  player,team,opponent,year,round,kicks,handball...
# 3  Jordan Dawson,ADE,NTH,2023,16,22,6,8,8,0,0,2,0...
# 4  Reilly O'Brien,ADE,NTH,2023,16,7,8,4,5,52,90,2...

# %%
df.groupby('player').mean().cbas.reset_index().sort_values('cbas', ascending = False).head(30)
# Out:
#                   player       cbas
# 35    Bailey J. Williams  25.071429
# 558       Todd Goldstein  24.769231
# 350         Lachie Neale  24.357143
# 550            Tim Kelly  24.285714
# 486       Reilly O'Brien  24.000000
# 491         Rhys Stanley  24.000000
# 443            Ned Moyle  24.000000
# 107       Clayton Oliver  24.000000
# 566            Tom Green  23.461538
# 343        Kieren Briggs  23.000000
# 540     Stephen Coniglio  22.928571
# 407          Matt Rowell  22.928571
# 396         Mark Blicavs  22.928571
# 139         Darcy Parish  22.888889
# 549          Tim English  22.785714
# 380  Luke Davies-Uniacke  22.714286
# 385          Luke Parker  22.615385
# 79          Caleb Serong  22.500000
# 472      Oscar McInerney  22.428571
# 313         Josh Dunkley  22.428571
# 404           Matt Flynn  22.222222
# 498           Rory Laird  22.214286
# 568           Tom Hickey  22.200000
# 533           Sean Darcy  22.083333
# 557       Toby Nankervis  22.000000
# ...
