# %%
import os
import pandas as pd

# %%
os.getcwd()
# Out:
# '/Users/caseyh/Desktop/footy/data_wrangling'

# %%
path = '/Users/caseyh/Desktop/footy/player_stats.csv'

# %%
tmp = pd.read_csv(path)
tmp.head()
# Out:
#             Player round       team opponent  Disposals  Kicks  Handballs  \
# 0      Bowey, Jake    R1  melbourne       WB       17.0   10.0        7.0
# 1  Brayshaw, Angus    R1  melbourne       WB       22.0   14.0        8.0
# 2       Brown, Ben    R1  melbourne       WB       15.0   12.0        3.0
# 3   Chandler, Kade    R1  melbourne       WB       16.0   11.0        5.0
# 4  Fritsch, Bayley    R1  melbourne       WB        NaN    NaN        NaN
#
#    Goals  Behinds  Marks  ...  Goal Assists  Frees  Frees Against  Inside 50s  \
# 0    0.0      0.0    3.0  ...           0.0    1.0            0.0         3.0
# 1    0.0      0.0   10.0  ...           0.0    1.0            1.0         2.0
# 2    4.0      1.0    7.0  ...           1.0    1.0            0.0         2.0
# 3    1.0      2.0    8.0  ...           2.0    1.0            0.0         4.0
# 4    NaN      NaN    NaN  ...           NaN    NaN            NaN         NaN
#
# ...

# %%
tmp.groupby(['opponent']).mean()
# Out:
#           Disposals     Kicks  Handballs     Goals   Behinds     Marks  \
# opponent
# AD        14.759197  8.625418   6.133779  0.508361  0.367893  3.110368
# BL        16.006689  9.096990   6.909699  0.515050  0.327759  3.739130
# CA        15.468944  9.282609   6.186335  0.481366  0.357143  3.894410
# CW        15.806020  9.056856   6.749164  0.411371  0.408027  4.020067
# ES        16.153846  9.665552   6.488294  0.501672  0.421405  4.464883
# FR        15.521739  9.207358   6.314381  0.545151  0.367893  3.836120
# GC        15.521739  9.324415   6.197324  0.538462  0.381271  3.872910
# GE        15.123746  9.140468   5.983278  0.545151  0.357860  3.819398
# GW        15.944099  9.391304   6.552795  0.543478  0.422360  3.866460
# HW        15.886288  9.558528   6.327759  0.608696  0.367893  4.377926
# ME        15.468227  9.113712   6.354515  0.451505  0.334448  3.819398
# NM        16.232919  9.729814   6.503106  0.655280  0.413043  4.509317
# ...

# %%
tmp.groupby(['opponent', 'round']).sum().sort_values('Disposals',ascending = False).dropna().head(20)
# Out:
#                 Disposals  Kicks  Handballs  Goals  Behinds  Marks  \
# opponent round
# GE       R12        400.0  229.0      171.0   10.0     14.0  111.0
# AD       R10        399.0  225.0      174.0   11.0     17.0   77.0
# BL       R3         385.0  231.0      154.0   10.0      6.0   99.0
# PA       R13        381.0  213.0      168.0   13.0      7.0   91.0
# GW       R8         380.0  223.0      157.0   13.0      5.0   97.0
# ME       R1         374.0  208.0      166.0    9.0      9.0   77.0
# FR       R6         373.0  207.0      166.0   17.0     14.0   81.0
# NM       R14        369.0  204.0      165.0   15.0     11.0   84.0
# GC       R11        365.0  215.0      150.0   11.0      9.0   87.0
# RI       R4         364.0  239.0      125.0   12.0     10.0   93.0
# HW       R7         363.0  204.0      159.0   14.0     10.0   97.0
# SK       R2         363.0  210.0      153.0    5.0      9.0  111.0
# CA       R9         362.0  232.0      130.0   11.0     10.0  101.0
# ...
